# %% [markdown]
# # Preprocessing & Tokenization

# %%
import gensim
import pandas as pd

# %%
df = pd.read_json("Cell_Phones_and_Accessories_5.json",lines=True)
df.head()
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
# 2  These are awesome and make my phone look so st...        5
# 3  Item arrived in great time and was in perfect ...        4
# 4  awesome! stays on, and looks great. can be use...        5
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# 1                      Really great product.      1389657600  01 14, 2014
# 2                             LOVE LOVE LOVE      1403740800  06 26, 2014
# 3                                      Cute!      1382313600  10 21, 2013
# 4  leopard home button sticker for iphone 4s      1359849600   02 3, 2013

# %%
df.shape
# Out:
# (194439, 9)

# %%
df['reviewText'][0]
# Out:
# "They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again"

# %%
# verilen metni küçük harflere çevirir, noktalama işaretlerini kaldırır ve kelimeleri tokenize eder (yani, kelimeleri ayrı ayrı ele alır)

gensim.utils.simple_preprocess("They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again")
# Out:
# ['they',
#  'look',
#  'good',
#  'and',
#  'stick',
#  'good',
#  'just',
#  'don',
#  'like',
#  'the',
#  'rounded',
#  'shape',
#  'because',
#  'was',
#  'always',
#  'bumping',
#  'it',
#  'and',
#  'siri',
#  'kept',
#  'popping',
#  'up',
#  'and',
#  'it',
#  'was',
#  'irritating',
#  'just',
#  'won',
#  'buy',
#  'product',
#  'like',
#  'this',
#  'again']

# %%
review_text = df['reviewText'].apply(gensim.utils.simple_preprocess)
review_text.head()
# Out:
# 0    [they, look, good, and, stick, good, just, don...
# 1    [these, stickers, work, like, the, review, say...
# 2    [these, are, awesome, and, make, my, phone, lo...
# 3    [item, arrived, in, great, time, and, was, in,...
# 4    [awesome, stays, on, and, looks, great, can, b...
# Name: reviewText, dtype: object

# %% [markdown]
# ## Word2Vec Model eğitimi

# %%
model = gensim.models.Word2Vec(window=10,           # bir cümlenin içindeki kelime sayısı
                               vector_size=100,     # kelime vektörlerinin boyutu
                               min_count=2,         # modeldeki kelime sayısı
                               sg=1)                # skip-gram modeli

# %% [markdown]
# ### kelime dağarcığını (vocab) oluştur

# %%
model.build_vocab(review_text) # modeli eğitmek için kelime haznesi oluşturur

# %%
model.epochs    # modeli eğitmek için kaç kez veri setini geçeceğini belirler
# Out:
# 5

# %%
model.window    # bir cümlenin içindeki kelime sayısı
# Out:
# 10

# %%
model.train(review_text, total_examples=model.corpus_count, epochs = model.epochs) # modeli eğitmek için veri setini kullanır
# Out:
# (61508824, 83868975)

# %%
model.corpus_count # modelin eğitim veri setindeki kelime sayısı
# Out:
# 194439

# %%
model.save("./final_word2vec.model")

# %% [markdown]
# ## Benzer Kelimeleri ve Kelimeler Arasındaki Benzerliği Bulun

# %%
model.wv.most_similar("bad")  # kelimenin en yakın kelimelerini bulur
# Out:
# [('terrible', 0.734882652759552),
#  ('horrible', 0.7063153386116028),
#  ('pathetic', 0.6608651876449585),
#  ('good', 0.6555846333503723),
#  ('poor', 0.6496292948722839),
#  ('okay', 0.6443062424659729),
#  ('guess', 0.641335129737854),
#  ('liike', 0.640103816986084),
#  ('crappy', 0.637427806854248),
#  ('ok', 0.6323232054710388)]

# %%
model.wv.similarity(w1='cheap',w2 = 'inexpensive')   # iki kelime arasındaki benzerliği bulur
# Out:
# 0.62215537

# %%
matrix = model.wv.vectors # kelime vektörlerini döndürür

print(f"shape of the word embedding matrix is {matrix.shape}")    # kelime vektörlerinin şeklini döndürür
# Out:
# shape of the word embedding matrix is (35561, 100)

# %%
W_out = model.syn1neg
W_out.shape # çıktı ağırlıklarının şeklini döndürür
# Out:
# (35561, 100)

# %%
#https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4
import random
random_word = random.choice(model.wv.index_to_key) # rastgele bir kelime seçer
random_word
# Out:
# 'spots'

# %%
vocab_list = list(model.wv.index_to_key)

# %%
len(vocab_list)
# Out:
# 35561

# %%
vocab_list
# Out:
# ['the',
#  'it',
#  'and',
#  'to',
#  'is',
#  'this',
#  'of',
#  'for',
#  'my',
#  'that',
#  'in',
#  'on',
#  'phone',
#  'with',
#  'you',
#  'case',
#  'but',
#  'have',
#  'not',
#  'was',
#  'as',
#  'so',
#  'one',
#  'very',
#  'are',
#  'like',
#  'if',
#  'be',
#  'can',
#  'or',
#  'great',
#  'your',
#  'at',
#  'when',
#  'use',
#  'screen',
#  'just',
#  'good',
#  'all',
#  'they',
#  'battery',
#  'from',
#  'would',
#  'out',
#  'will',
#  'well',
#  'an',
#  'has',
#  'iphone',
#  'had',
#  'get',
#  'charge',
#  'up',
#  'no',
#  'me',
#  'than',
#  'more',
#  'only',
#  'charger',
#  'about',
#  'product',
#  'other',
#  'there',
#  'really',
#  'time',
#  'also',
#  'off',
#  'these',
#  'which',
#  'works',
#  'does',
#  'because',
#  'do',
#  'don',
#  'them',
#  'much',
#  'back',
#  'what',
#  'nice',
#  'little',
#  'price',
#  'love',
#  'usb',
#  'its',
#  'some',
#  'quality',
#  'charging',
#  'work',
#  'fit',
#  'any',
#  'easy',
#  'even',
#  've',
#  'device',
#  'too',
#  'after',
#  'still',
#  'used',
#  'protector',
#  'while',
#  'power',
#  'using',
#  'got',
#  'better',
#  'am',
#  'bought',
#  'two',
#  'now',
#  'by',
#  'cable',
#  'first',
#  'recommend',
#  'into',
#  'need',
#  'fits',
#  'doesn',
#  'then',
#  'over',
#  'cover',
#  'looks',
#  'buy',
#  'did',
#  'car',
#  'put',
#  'without',
#  'how',
#  'protection',
#  'new',
#  'cases',
#  'way',
#  'sound',
#  'around',
#  'been',
#  'galaxy',
#  'go',
#  'could',
#  'same',
#  'thing',
#  'bluetooth',
#  'hard',
#  'want',
#  'make',
#  'devices',
#  'samsung',
#  'long',
#  'pretty',
#  'enough',
#  'headset',
#  'few',
#  'bit',
#  'phones',
#  'perfect',
#  'plastic',
#  'look',
#  'made',
#  'best',
#  'most',
#  'right',
#  'feel',
#  'since',
#  'take',
#  'see',
#  'button',
#  'both',
#  'down',
#  'small',
#  'didn',
#  'looking',
#  'were',
#  'another',
#  'day',
#  'keep',
#  'lot',
#  'easily',
#  'think',
#  'however',
#  'problem',
#  'came',
#  'far',
#  'color',
#  'perfectly',
#  'ear',
#  'note',
#  'port',
#  'makes',
#  'though',
#  'before',
#  'comes',
#  'ipad',
#  'know',
#  'again',
#  'we',
#  'their',
#  'many',
#  'review',
#  'light',
#  'say',
#  'sure',
#  'find',
#  're',
#  'plug',
#  'buttons',
#  'seems',
#  'fine',
#  'something',
#  'different',
#  'where',
#  'never',
#  'clear',
#  'should',
#  'side',
#  'unit',
#  'able',
#  'cheap',
#  'times',
#  'being',
#  'design',
#  'going',
#  'once',
#  'volume',
#  'having',
#  'charged',
#  'pocket',
#  'music',
#  'purchased',
#  'actually',
#  'apple',
#  'life',
#  'tried',
#  'hours',
#  'big',
#  'last',
#  'through',
#  'she',
#  'hold',
#  'overall',
#  'amazon',
#  'size',
#  'always',
#  'may',
#  'happy',
#  'who',
#  'top',
#  'come',
#  'll',
#  'give',
#  'speaker',
#  'item',
#  'people',
#  'getting',
#  'rubber',
#  'found',
#  'protectors',
#  'touch',
#  'cord',
#  'black',
#  'worth',
#  'days',
#  'worked',
#  'protect',
#  'those',
#  'camera',
#  'definitely',
#  'charges',
#  'otterbox',
#  'every',
#  'less',
#  'feels',
#  'full',
#  'received',
#  'place',
#  'headphones',
#  'bad',
#  'front',
#  'fast',
#  'quite',
#  'end',
#  'part',
#  'stars',
#  'issue',
#  'bottom',
#  'months',
#  'purchase',
#  'extra',
#  'money',
#  'ordered',
#  'call',
#  'micro',
#  'batteries',
#  'her',
#  'stylus',
#  'almost',
#  'android',
#  'several',
#  'cell',
#  'ports',
#  'isn',
#  'away',
#  'try',
#  'set',
#  'high',
#  'he',
#  'pack',
#  'highly',
#  'things',
#  'excellent',
#  'took',
#  'white',
#  'won',
#  'here',
#  'yet',
#  'hand',
#  'ever',
#  'home',
#  'needed',
#  'dropped',
#  'thought',
#  'free',
#  'problems',
#  'blue',
#  'wanted',
#  'job',
#  'couple',
#  'nexus',
#  'mount',
#  'probably',
#  'issues',
#  'itself',
#  'original',
#  'mah',
#  'piece',
#  'everything',
#  'update',
#  'quickly',
#  'anything',
#  'might',
#  'three',
#  'old',
#  'longer',
#  'reviews',
#  'box',
#  'either',
#  'clip',
#  'adapter',
#  'tablet',
#  'why',
#  'wall',
#  'drop',
#  'said',
#  'chargers',
#  'left',
#  'card',
#  'remove',
#  'others',
#  'bulky',
#  'order',
#  'bubbles',
#  'cables',
#  'wife',
#  'slim',
#  'such',
#  'own',
#  'turn',
#  'exactly',
#  'built',
#  'calls',
#  'working',
#  'second',
#  'fact',
#  'htc',
#  'deal',
#  'anyone',
#  'ipod',
#  'products',
#  'colors',
#  'wish',
#  'awesome',
#  'feature',
#  'thin',
#  'stand',
#  'simple',
#  'protects',
#  'included',
#  'already',
#  'grip',
#  'went',
#  'nothing',
#  'fully',
#  'ones',
#  'glass',
#  'inside',
#  'etc',
#  'plus',
#  'voice',
#  'expected',
#  'low',
#  'especially',
#  'least',
#  'dust',
#  'carry',
#  'cute',
#  'our',
#  'plugged',
#  'comfortable',
#  'between',
#  'weeks',
#  'tell',
#  'super',
#  'hear',
#  'although',
#  'solid',
#  'year',
#  'add',
#  'seem',
#  'gets',
#  'install',
#  'ok',
#  'cut',
#  'until',
#  'replacement',
#  'service',
#  'short',
#  'soft',
#  'read',
#  'each',
#  'let',
#  'sturdy',
#  'hands',
#  'covers',
#  'app',
#  'audio',
#  'reason',
#  'buying',
#  'durable',
#  'mine',
#  'edges',
#  'takes',
#  'mobile',
#  'difficult',
#  'motorola',
#  'maybe',
#  'instead',
#  'week',
#  'wasn',
#  'kind',
#  'led',
#  'easier',
#  'must',
#  'large',
#  'material',
#  'bulk',
#  'protective',
#  'haven',
#  'holds',
#  'line',
#  'apps',
#  'slightly',
#  'minutes',
#  'under',
#  'open',
#  'real',
#  'star',
#  'years',
#  'needs',
#  'weight',
#  'completely',
#  'month',
#  'press',
#  'change',
#  'features',
#  'scratches',
#  'heavy',
#  'next',
#  'droid',
#  'dock',
#  'type',
#  'point',
#  'holster',
#  'brand',
#  'expensive',
#  'picture',
#  'sometimes',
#  'his',
#  'sides',
#  'cool',
#  'gave',
#  'wireless',
#  'pen',
#  'arrived',
#  'belt',
#  'wouldn',
#  'noise',
#  'version',
#  'stay',
#  'pay',
#  'goes',
#  'store',
#  'cost',
#  'clean',
#  'surface',
#  'trying',
#  'provides',
#  'amazing',
#  'connection',
#  'shipping',
#  'wear',
#  'done',
#  'mini',
#  'capacity',
#  'decent',
#  'broke',
#  'smooth',
#  'standard',
#  'due',
#  'tight',
#  'protected',
#  'play',
#  'allows',
#  'pros',
#  'else',
#  'expect',
#  'fall',
#  'switch',
#  'wrong',
#  'quick',
#  'seller',
#  'simply',
#  'test',
#  'face',
#  'oem',
#  'instructions',
#  'rather',
#  'available',
#  'loves',
#  'liked',
#  'making',
#  'handy',
#  'designed',
#  'company',
#  'provided',
#  'loved',
#  'external',
#  'customer',
#  'portable',
#  'half',
#  'smartphone',
#  'often',
#  'gps',
#  'close',
#  'started',
#  'access',
#  'water',
#  'computer',
#  'edge',
#  'gives',
#  'running',
#  'connector',
#  'travel',
#  'replace',
#  'package',
#  'provide',
#  'video',
#  'decided',
#  'cannot',
#  'extremely',
#  'help',
#  'pleased',
#  'run',
#  'silicone',
#  'leave',
#  'guess',
#  'recommended',
#  'connect',
#  'verizon',
#  'experience',
#  'pair',
#  'range',
#  'tip',
#  'during',
#  'nicely',
#  'means',
#  'bright',
#  'similar',
#  'keeps',
#  'purse',
#  'apply',
#  'thick',
#  'scratch',
#  'couldn',
#  'someone',
#  'uses',
#  'kindle',
#  'red',
#  'headphone',
#  'taking',
#  'air',
#  'compared',
#  'within',
#  'outlet',
#  'break',
#  'finally',
#  'connected',
#  'extended',
#  'absolutely',
#  'room',
#  'bag',
#  'jack',
#  'stick',
#  'output',
#  'packaging',
#  'holding',
#  'headsets',
#  'says',
#  'usually',
#  'smart',
#  'start',
#  'user',
#  'yes',
#  'finish',
#  'dual',
#  'anker',
#  'holder',
#  'model',
#  'smaller',
#  'blackberry',
#  'data',
#  'disappointed',
#  'pink',
#  'loose',
#  'larger',
#  'useful',
#  'night',
#  'strong',
#  'seen',
#  'looked',
#  'mind',
#  'multiple',
#  'show',
#  'four',
#  'person',
#  'installed',
#  'push',
#  'whole',
#  'slide',
#  'head',
#  'myself',
#  'google',
#  'amount',
#  'past',
#  'value',
#  'speakers',
#  'jabra',
#  'talk',
#  'together',
#  'snug',
#  'thanks',
#  'pictures',
#  'cons',
#  'display',
#  'putting',
#  'idea',
#  'lg',
#  'friends',
#  'fairly',
#  'non',
#  'outside',
#  'everyone',
#  'doing',
#  'style',
#  'support',
#  'ears',
#  'area',
#  'noticed',
#  'cards',
#  'via',
#  'against',
#  'signal',
#  'drops',
#  'along',
#  'shell',
#  'friend',
#  'tested',
#  'return',
#  'lights',
#  'unless',
#  'paid',
#  'number',
#  'finger',
#  'prefer',
#  'sent',
#  'nokia',
#  'sleek',
#  'control',
#  'added',
#  'offers',
#  'huge',
#  'hour',
#  'loud',
#  'tpu',
#  'watch',
#  'adds',
#  'difference',
#  'sim',
#  'given',
#  'otherwise',
#  'recharge',
#  'leather',
#  'daughter',
#  'compact',
#  'damage',
#  'secure',
#  'defender',
#  'onto',
#  'annoying',
#  'convenient',
#  'properly',
#  'bumper',
#  'option',
#  'believe',
#  'keyboard',
#  'impressed',
#  'complaints',
#  'allow',
#  'metal',
#  'dont',
#  'flat',
#  'normal',
#  'level',
#  'market',
#  'cheaper',
#  'course',
#  'function',
#  'later',
#  'faster',
#  'ago',
#  'worry',
#  'apart',
#  'house',
#  'turned',
#  'matte',
#  'slip',
#  'evo',
#  'ac',
#  'amp',
#  'system',
#  'mode',
#  'glad',
#  'favorite',
#  'previous',
#  'snap',
#  'owned',
#  'single',
#  'us',
#  'driving',
#  'soon',
#  'lost',
#  'flash',
#  'plan',
#  'advertised',
#  'pull',
#  'regular',
#  'build',
#  'tablets',
#  'juice',
#  'listen',
#  'beautiful',
#  'feet',
#  'twice',
#  'tiny',
#  'hd',
#  'stays',
#  'film',
#  'rate',
#  'corners',
#  'current',
#  'length',
#  'important',
#  'gift',
#  'suction',
#  'gs',
#  'husband',
#  'coming',
#  'complaint',
#  'slippery',
#  'kept',
#  'performance',
#  'hope',
#  'stock',
#  'sample',
#  'supposed',
#  'unfortunately',
#  'bank',
#  'thank',
#  'matter',
#  'shows',
#  'notice',
#  'care',
#  'slot',
#  'attached',
#  'plantronics',
#  'above',
#  'cords',
#  'five',
#  'lightning',
#  'satisfied',
#  'rating',
#  'installation',
#  'sounds',
#  'stereo',
#  'covered',
#  'wallet',
#  'except',
#  'listening',
#  'bigger',
#  'controls',
#  'pieces',
#  'earbuds',
#  'near',
#  'cause',
#  'family',
#  'stuff',
#  'higher',
#  'application',
#  'cloth',
#  'warranty',
#  'answer',
#  'items',
#  'kickstand',
#  'careful',
#  'move',
#  'mp',
#  'lose',
#  'text',
#  'helps',
#  'including',
#  'okay',
#  'radio',
#  'offer',
#  'plugs',
#  'choice',
#  'anyway',
#  'described',
#  'desk',
#  'surprised',
#  'iphones',
#  'green',
#  'felt',
#  'backup',
#  'today',
#  'send',
#  'bass',
#  'spare',
#  'ended',
#  'minor',
#  'pro',
#  'pairing',
#  'space',
#  'beat',
#  'check',
#  'gb',
#  'unlike',
#  'belkin',
#  'held',
#  'barely',
#  'speed',
#  'laptop',
#  'skin',
#  'flip',
#  'carrying',
#  'poor',
#  'mm',
#  'email',
#  'purpose',
#  'reading',
#  'microphone',
#  'spigen',
#  'flimsy',
#  'main',
#  'considering',
#  'seemed',
#  'trent',
#  'keeping',
#  'saw',
#  'glare',
#  'wait',
#  'usage',
#  'true',
#  'dead',
#  'based',
#  'mic',
#  'credit',
#  'options',
#  'wifi',
#  'constantly',
#  'talking',
#  'protecting',
#  'broken',
#  'manufacturer',
#  'solution',
#  'sticky',
#  'opinion',
#  'immediately',
#  'office',
#  'inexpensive',
#  'aren',
#  'live',
#  'fantastic',
#  'totally',
#  'actual',
#  'spend',
#  'son',
#  'placed',
#  'playing',
#  'hole',
#  'lighter',
#  'thicker',
#  'corner',
#  'road',
#  'windows',
#  'hot',
#  'opening',
#  'trouble',
#  'giving',
#  'scratched',
#  'additional',
#  'tech',
#  'player',
#  'otter',
#  'lasted',
#  'name',
#  'fingers',
#  'position',
#  'stuck',
#  'arm',
#  'seconds',
#  'lasts',
#  'across',
#  'software',
#  'hit',
#  'earpiece',
#  'base',
#  'certainly',
#  'tape',
#  'entire',
#  'videos',
#  'dash',
#  'shipped',
#  'armor',
#  'likely',
#  'flashlight',
#  'turns',
#  'possible',
#  'waste',
#  'feeling',
#  'lightweight',
#  'fell',
#  'outer',
#  'replaced',
#  'nearly',
#  'fire',
#  'paired',
#  'appears',
#  'indicator',
#  'contact',
#  'honest',
#  'cup',
#  'none',
#  'ability',
#  'clearly',
#  'trip',
#  'stylish',
#  'falls',
#  'securely',
#  'pouch',
#  'sprint',
#  'removed',
#  'pick',
#  'lip',
#  'windshield',
#  'save',
#  'pad',
#  'lower',
#  'daily',
#  'flexible',
#  'drive',
#  'photos',
#  'addition',
#  'tab',
#  'directly',
#  'older',
#  'somewhat',
#  'gotten',
#  'whatever',
#  'form',
#  'pin',
#  'dirty',
#  'texture',
#  'lint',
#  'basic',
#  'behind',
#  ...]

# %%
model.wv ['bad'] # kelimenin vektörünü döndürür

# %%
vocab_len = len(vocab_list)

# %%
model.wv.index_to_key # kelime indekslerini döndürür
# Out:
# ['the',
#  'it',
#  'and',
#  'to',
#  'is',
#  'this',
#  'of',
#  'for',
#  'my',
#  'that',
#  'in',
#  'on',
#  'phone',
#  'with',
#  'you',
#  'case',
#  'but',
#  'have',
#  'not',
#  'was',
#  'as',
#  'so',
#  'one',
#  'very',
#  'are',
#  'like',
#  'if',
#  'be',
#  'can',
#  'or',
#  'great',
#  'your',
#  'at',
#  'when',
#  'use',
#  'screen',
#  'just',
#  'good',
#  'all',
#  'they',
#  'battery',
#  'from',
#  'would',
#  'out',
#  'will',
#  'well',
#  'an',
#  'has',
#  'iphone',
#  'had',
#  'get',
#  'charge',
#  'up',
#  'no',
#  'me',
#  'than',
#  'more',
#  'only',
#  'charger',
#  'about',
#  'product',
#  'other',
#  'there',
#  'really',
#  'time',
#  'also',
#  'off',
#  'these',
#  'which',
#  'works',
#  'does',
#  'because',
#  'do',
#  'don',
#  'them',
#  'much',
#  'back',
#  'what',
#  'nice',
#  'little',
#  'price',
#  'love',
#  'usb',
#  'its',
#  'some',
#  'quality',
#  'charging',
#  'work',
#  'fit',
#  'any',
#  'easy',
#  'even',
#  've',
#  'device',
#  'too',
#  'after',
#  'still',
#  'used',
#  'protector',
#  'while',
#  'power',
#  'using',
#  'got',
#  'better',
#  'am',
#  'bought',
#  'two',
#  'now',
#  'by',
#  'cable',
#  'first',
#  'recommend',
#  'into',
#  'need',
#  'fits',
#  'doesn',
#  'then',
#  'over',
#  'cover',
#  'looks',
#  'buy',
#  'did',
#  'car',
#  'put',
#  'without',
#  'how',
#  'protection',
#  'new',
#  'cases',
#  'way',
#  'sound',
#  'around',
#  'been',
#  'galaxy',
#  'go',
#  'could',
#  'same',
#  'thing',
#  'bluetooth',
#  'hard',
#  'want',
#  'make',
#  'devices',
#  'samsung',
#  'long',
#  'pretty',
#  'enough',
#  'headset',
#  'few',
#  'bit',
#  'phones',
#  'perfect',
#  'plastic',
#  'look',
#  'made',
#  'best',
#  'most',
#  'right',
#  'feel',
#  'since',
#  'take',
#  'see',
#  'button',
#  'both',
#  'down',
#  'small',
#  'didn',
#  'looking',
#  'were',
#  'another',
#  'day',
#  'keep',
#  'lot',
#  'easily',
#  'think',
#  'however',
#  'problem',
#  'came',
#  'far',
#  'color',
#  'perfectly',
#  'ear',
#  'note',
#  'port',
#  'makes',
#  'though',
#  'before',
#  'comes',
#  'ipad',
#  'know',
#  'again',
#  'we',
#  'their',
#  'many',
#  'review',
#  'light',
#  'say',
#  'sure',
#  'find',
#  're',
#  'plug',
#  'buttons',
#  'seems',
#  'fine',
#  'something',
#  'different',
#  'where',
#  'never',
#  'clear',
#  'should',
#  'side',
#  'unit',
#  'able',
#  'cheap',
#  'times',
#  'being',
#  'design',
#  'going',
#  'once',
#  'volume',
#  'having',
#  'charged',
#  'pocket',
#  'music',
#  'purchased',
#  'actually',
#  'apple',
#  'life',
#  'tried',
#  'hours',
#  'big',
#  'last',
#  'through',
#  'she',
#  'hold',
#  'overall',
#  'amazon',
#  'size',
#  'always',
#  'may',
#  'happy',
#  'who',
#  'top',
#  'come',
#  'll',
#  'give',
#  'speaker',
#  'item',
#  'people',
#  'getting',
#  'rubber',
#  'found',
#  'protectors',
#  'touch',
#  'cord',
#  'black',
#  'worth',
#  'days',
#  'worked',
#  'protect',
#  'those',
#  'camera',
#  'definitely',
#  'charges',
#  'otterbox',
#  'every',
#  'less',
#  'feels',
#  'full',
#  'received',
#  'place',
#  'headphones',
#  'bad',
#  'front',
#  'fast',
#  'quite',
#  'end',
#  'part',
#  'stars',
#  'issue',
#  'bottom',
#  'months',
#  'purchase',
#  'extra',
#  'money',
#  'ordered',
#  'call',
#  'micro',
#  'batteries',
#  'her',
#  'stylus',
#  'almost',
#  'android',
#  'several',
#  'cell',
#  'ports',
#  'isn',
#  'away',
#  'try',
#  'set',
#  'high',
#  'he',
#  'pack',
#  'highly',
#  'things',
#  'excellent',
#  'took',
#  'white',
#  'won',
#  'here',
#  'yet',
#  'hand',
#  'ever',
#  'home',
#  'needed',
#  'dropped',
#  'thought',
#  'free',
#  'problems',
#  'blue',
#  'wanted',
#  'job',
#  'couple',
#  'nexus',
#  'mount',
#  'probably',
#  'issues',
#  'itself',
#  'original',
#  'mah',
#  'piece',
#  'everything',
#  'update',
#  'quickly',
#  'anything',
#  'might',
#  'three',
#  'old',
#  'longer',
#  'reviews',
#  'box',
#  'either',
#  'clip',
#  'adapter',
#  'tablet',
#  'why',
#  'wall',
#  'drop',
#  'said',
#  'chargers',
#  'left',
#  'card',
#  'remove',
#  'others',
#  'bulky',
#  'order',
#  'bubbles',
#  'cables',
#  'wife',
#  'slim',
#  'such',
#  'own',
#  'turn',
#  'exactly',
#  'built',
#  'calls',
#  'working',
#  'second',
#  'fact',
#  'htc',
#  'deal',
#  'anyone',
#  'ipod',
#  'products',
#  'colors',
#  'wish',
#  'awesome',
#  'feature',
#  'thin',
#  'stand',
#  'simple',
#  'protects',
#  'included',
#  'already',
#  'grip',
#  'went',
#  'nothing',
#  'fully',
#  'ones',
#  'glass',
#  'inside',
#  'etc',
#  'plus',
#  'voice',
#  'expected',
#  'low',
#  'especially',
#  'least',
#  'dust',
#  'carry',
#  'cute',
#  'our',
#  'plugged',
#  'comfortable',
#  'between',
#  'weeks',
#  'tell',
#  'super',
#  'hear',
#  'although',
#  'solid',
#  'year',
#  'add',
#  'seem',
#  'gets',
#  'install',
#  'ok',
#  'cut',
#  'until',
#  'replacement',
#  'service',
#  'short',
#  'soft',
#  'read',
#  'each',
#  'let',
#  'sturdy',
#  'hands',
#  'covers',
#  'app',
#  'audio',
#  'reason',
#  'buying',
#  'durable',
#  'mine',
#  'edges',
#  'takes',
#  'mobile',
#  'difficult',
#  'motorola',
#  'maybe',
#  'instead',
#  'week',
#  'wasn',
#  'kind',
#  'led',
#  'easier',
#  'must',
#  'large',
#  'material',
#  'bulk',
#  'protective',
#  'haven',
#  'holds',
#  'line',
#  'apps',
#  'slightly',
#  'minutes',
#  'under',
#  'open',
#  'real',
#  'star',
#  'years',
#  'needs',
#  'weight',
#  'completely',
#  'month',
#  'press',
#  'change',
#  'features',
#  'scratches',
#  'heavy',
#  'next',
#  'droid',
#  'dock',
#  'type',
#  'point',
#  'holster',
#  'brand',
#  'expensive',
#  'picture',
#  'sometimes',
#  'his',
#  'sides',
#  'cool',
#  'gave',
#  'wireless',
#  'pen',
#  'arrived',
#  'belt',
#  'wouldn',
#  'noise',
#  'version',
#  'stay',
#  'pay',
#  'goes',
#  'store',
#  'cost',
#  'clean',
#  'surface',
#  'trying',
#  'provides',
#  'amazing',
#  'connection',
#  'shipping',
#  'wear',
#  'done',
#  'mini',
#  'capacity',
#  'decent',
#  'broke',
#  'smooth',
#  'standard',
#  'due',
#  'tight',
#  'protected',
#  'play',
#  'allows',
#  'pros',
#  'else',
#  'expect',
#  'fall',
#  'switch',
#  'wrong',
#  'quick',
#  'seller',
#  'simply',
#  'test',
#  'face',
#  'oem',
#  'instructions',
#  'rather',
#  'available',
#  'loves',
#  'liked',
#  'making',
#  'handy',
#  'designed',
#  'company',
#  'provided',
#  'loved',
#  'external',
#  'customer',
#  'portable',
#  'half',
#  'smartphone',
#  'often',
#  'gps',
#  'close',
#  'started',
#  'access',
#  'water',
#  'computer',
#  'edge',
#  'gives',
#  'running',
#  'connector',
#  'travel',
#  'replace',
#  'package',
#  'provide',
#  'video',
#  'decided',
#  'cannot',
#  'extremely',
#  'help',
#  'pleased',
#  'run',
#  'silicone',
#  'leave',
#  'guess',
#  'recommended',
#  'connect',
#  'verizon',
#  'experience',
#  'pair',
#  'range',
#  'tip',
#  'during',
#  'nicely',
#  'means',
#  'bright',
#  'similar',
#  'keeps',
#  'purse',
#  'apply',
#  'thick',
#  'scratch',
#  'couldn',
#  'someone',
#  'uses',
#  'kindle',
#  'red',
#  'headphone',
#  'taking',
#  'air',
#  'compared',
#  'within',
#  'outlet',
#  'break',
#  'finally',
#  'connected',
#  'extended',
#  'absolutely',
#  'room',
#  'bag',
#  'jack',
#  'stick',
#  'output',
#  'packaging',
#  'holding',
#  'headsets',
#  'says',
#  'usually',
#  'smart',
#  'start',
#  'user',
#  'yes',
#  'finish',
#  'dual',
#  'anker',
#  'holder',
#  'model',
#  'smaller',
#  'blackberry',
#  'data',
#  'disappointed',
#  'pink',
#  'loose',
#  'larger',
#  'useful',
#  'night',
#  'strong',
#  'seen',
#  'looked',
#  'mind',
#  'multiple',
#  'show',
#  'four',
#  'person',
#  'installed',
#  'push',
#  'whole',
#  'slide',
#  'head',
#  'myself',
#  'google',
#  'amount',
#  'past',
#  'value',
#  'speakers',
#  'jabra',
#  'talk',
#  'together',
#  'snug',
#  'thanks',
#  'pictures',
#  'cons',
#  'display',
#  'putting',
#  'idea',
#  'lg',
#  'friends',
#  'fairly',
#  'non',
#  'outside',
#  'everyone',
#  'doing',
#  'style',
#  'support',
#  'ears',
#  'area',
#  'noticed',
#  'cards',
#  'via',
#  'against',
#  'signal',
#  'drops',
#  'along',
#  'shell',
#  'friend',
#  'tested',
#  'return',
#  'lights',
#  'unless',
#  'paid',
#  'number',
#  'finger',
#  'prefer',
#  'sent',
#  'nokia',
#  'sleek',
#  'control',
#  'added',
#  'offers',
#  'huge',
#  'hour',
#  'loud',
#  'tpu',
#  'watch',
#  'adds',
#  'difference',
#  'sim',
#  'given',
#  'otherwise',
#  'recharge',
#  'leather',
#  'daughter',
#  'compact',
#  'damage',
#  'secure',
#  'defender',
#  'onto',
#  'annoying',
#  'convenient',
#  'properly',
#  'bumper',
#  'option',
#  'believe',
#  'keyboard',
#  'impressed',
#  'complaints',
#  'allow',
#  'metal',
#  'dont',
#  'flat',
#  'normal',
#  'level',
#  'market',
#  'cheaper',
#  'course',
#  'function',
#  'later',
#  'faster',
#  'ago',
#  'worry',
#  'apart',
#  'house',
#  'turned',
#  'matte',
#  'slip',
#  'evo',
#  'ac',
#  'amp',
#  'system',
#  'mode',
#  'glad',
#  'favorite',
#  'previous',
#  'snap',
#  'owned',
#  'single',
#  'us',
#  'driving',
#  'soon',
#  'lost',
#  'flash',
#  'plan',
#  'advertised',
#  'pull',
#  'regular',
#  'build',
#  'tablets',
#  'juice',
#  'listen',
#  'beautiful',
#  'feet',
#  'twice',
#  'tiny',
#  'hd',
#  'stays',
#  'film',
#  'rate',
#  'corners',
#  'current',
#  'length',
#  'important',
#  'gift',
#  'suction',
#  'gs',
#  'husband',
#  'coming',
#  'complaint',
#  'slippery',
#  'kept',
#  'performance',
#  'hope',
#  'stock',
#  'sample',
#  'supposed',
#  'unfortunately',
#  'bank',
#  'thank',
#  'matter',
#  'shows',
#  'notice',
#  'care',
#  'slot',
#  'attached',
#  'plantronics',
#  'above',
#  'cords',
#  'five',
#  'lightning',
#  'satisfied',
#  'rating',
#  'installation',
#  'sounds',
#  'stereo',
#  'covered',
#  'wallet',
#  'except',
#  'listening',
#  'bigger',
#  'controls',
#  'pieces',
#  'earbuds',
#  'near',
#  'cause',
#  'family',
#  'stuff',
#  'higher',
#  'application',
#  'cloth',
#  'warranty',
#  'answer',
#  'items',
#  'kickstand',
#  'careful',
#  'move',
#  'mp',
#  'lose',
#  'text',
#  'helps',
#  'including',
#  'okay',
#  'radio',
#  'offer',
#  'plugs',
#  'choice',
#  'anyway',
#  'described',
#  'desk',
#  'surprised',
#  'iphones',
#  'green',
#  'felt',
#  'backup',
#  'today',
#  'send',
#  'bass',
#  'spare',
#  'ended',
#  'minor',
#  'pro',
#  'pairing',
#  'space',
#  'beat',
#  'check',
#  'gb',
#  'unlike',
#  'belkin',
#  'held',
#  'barely',
#  'speed',
#  'laptop',
#  'skin',
#  'flip',
#  'carrying',
#  'poor',
#  'mm',
#  'email',
#  'purpose',
#  'reading',
#  'microphone',
#  'spigen',
#  'flimsy',
#  'main',
#  'considering',
#  'seemed',
#  'trent',
#  'keeping',
#  'saw',
#  'glare',
#  'wait',
#  'usage',
#  'true',
#  'dead',
#  'based',
#  'mic',
#  'credit',
#  'options',
#  'wifi',
#  'constantly',
#  'talking',
#  'protecting',
#  'broken',
#  'manufacturer',
#  'solution',
#  'sticky',
#  'opinion',
#  'immediately',
#  'office',
#  'inexpensive',
#  'aren',
#  'live',
#  'fantastic',
#  'totally',
#  'actual',
#  'spend',
#  'son',
#  'placed',
#  'playing',
#  'hole',
#  'lighter',
#  'thicker',
#  'corner',
#  'road',
#  'windows',
#  'hot',
#  'opening',
#  'trouble',
#  'giving',
#  'scratched',
#  'additional',
#  'tech',
#  'player',
#  'otter',
#  'lasted',
#  'name',
#  'fingers',
#  'position',
#  'stuck',
#  'arm',
#  'seconds',
#  'lasts',
#  'across',
#  'software',
#  'hit',
#  'earpiece',
#  'base',
#  'certainly',
#  'tape',
#  'entire',
#  'videos',
#  'dash',
#  'shipped',
#  'armor',
#  'likely',
#  'flashlight',
#  'turns',
#  'possible',
#  'waste',
#  'feeling',
#  'lightweight',
#  'fell',
#  'outer',
#  'replaced',
#  'nearly',
#  'fire',
#  'paired',
#  'appears',
#  'indicator',
#  'contact',
#  'honest',
#  'cup',
#  'none',
#  'ability',
#  'clearly',
#  'trip',
#  'stylish',
#  'falls',
#  'securely',
#  'pouch',
#  'sprint',
#  'removed',
#  'pick',
#  'lip',
#  'windshield',
#  'save',
#  'pad',
#  'lower',
#  'daily',
#  'flexible',
#  'drive',
#  'photos',
#  'addition',
#  'tab',
#  'directly',
#  'older',
#  'somewhat',
#  'gotten',
#  'whatever',
#  'form',
#  'pin',
#  'dirty',
#  'texture',
#  'lint',
#  'basic',
#  'behind',
#  ...]

# %%
model.wv.key_to_index # kelime anahtarlarını döndürür
# Out:
# {'the': 0,
#  'it': 1,
#  'and': 2,
#  'to': 3,
#  'is': 4,
#  'this': 5,
#  'of': 6,
#  'for': 7,
#  'my': 8,
#  'that': 9,
#  'in': 10,
#  'on': 11,
#  'phone': 12,
#  'with': 13,
#  'you': 14,
#  'case': 15,
#  'but': 16,
#  'have': 17,
#  'not': 18,
#  'was': 19,
#  'as': 20,
#  'so': 21,
#  'one': 22,
#  'very': 23,
#  'are': 24,
#  'like': 25,
#  'if': 26,
#  'be': 27,
#  'can': 28,
#  'or': 29,
#  'great': 30,
#  'your': 31,
#  'at': 32,
#  'when': 33,
#  'use': 34,
#  'screen': 35,
#  'just': 36,
#  'good': 37,
#  'all': 38,
#  'they': 39,
#  'battery': 40,
#  'from': 41,
#  'would': 42,
#  'out': 43,
#  'will': 44,
#  'well': 45,
#  'an': 46,
#  'has': 47,
#  'iphone': 48,
#  'had': 49,
#  'get': 50,
#  'charge': 51,
#  'up': 52,
#  'no': 53,
#  'me': 54,
#  'than': 55,
#  'more': 56,
#  'only': 57,
#  'charger': 58,
#  'about': 59,
#  'product': 60,
#  'other': 61,
#  'there': 62,
#  'really': 63,
#  'time': 64,
#  'also': 65,
#  'off': 66,
#  'these': 67,
#  'which': 68,
#  'works': 69,
#  'does': 70,
#  'because': 71,
#  'do': 72,
#  'don': 73,
#  'them': 74,
#  'much': 75,
#  'back': 76,
#  'what': 77,
#  'nice': 78,
#  'little': 79,
#  'price': 80,
#  'love': 81,
#  'usb': 82,
#  'its': 83,
#  'some': 84,
#  'quality': 85,
#  'charging': 86,
#  'work': 87,
#  'fit': 88,
#  'any': 89,
#  'easy': 90,
#  'even': 91,
#  've': 92,
#  'device': 93,
#  'too': 94,
#  'after': 95,
#  'still': 96,
#  'used': 97,
#  'protector': 98,
#  'while': 99,
#  'power': 100,
#  'using': 101,
#  'got': 102,
#  'better': 103,
#  'am': 104,
#  'bought': 105,
#  'two': 106,
#  'now': 107,
#  'by': 108,
#  'cable': 109,
#  'first': 110,
#  'recommend': 111,
#  'into': 112,
#  'need': 113,
#  'fits': 114,
#  'doesn': 115,
#  'then': 116,
#  'over': 117,
#  'cover': 118,
#  'looks': 119,
#  'buy': 120,
#  'did': 121,
#  'car': 122,
#  'put': 123,
#  'without': 124,
#  'how': 125,
#  'protection': 126,
#  'new': 127,
#  'cases': 128,
#  'way': 129,
#  'sound': 130,
#  'around': 131,
#  'been': 132,
#  'galaxy': 133,
#  'go': 134,
#  'could': 135,
#  'same': 136,
#  'thing': 137,
#  'bluetooth': 138,
#  'hard': 139,
#  'want': 140,
#  'make': 141,
#  'devices': 142,
#  'samsung': 143,
#  'long': 144,
#  'pretty': 145,
#  'enough': 146,
#  'headset': 147,
#  'few': 148,
#  'bit': 149,
#  'phones': 150,
#  'perfect': 151,
#  'plastic': 152,
#  'look': 153,
#  'made': 154,
#  'best': 155,
#  'most': 156,
#  'right': 157,
#  'feel': 158,
#  'since': 159,
#  'take': 160,
#  'see': 161,
#  'button': 162,
#  'both': 163,
#  'down': 164,
#  'small': 165,
#  'didn': 166,
#  'looking': 167,
#  'were': 168,
#  'another': 169,
#  'day': 170,
#  'keep': 171,
#  'lot': 172,
#  'easily': 173,
#  'think': 174,
#  'however': 175,
#  'problem': 176,
#  'came': 177,
#  'far': 178,
#  'color': 179,
#  'perfectly': 180,
#  'ear': 181,
#  'note': 182,
#  'port': 183,
#  'makes': 184,
#  'though': 185,
#  'before': 186,
#  'comes': 187,
#  'ipad': 188,
#  'know': 189,
#  'again': 190,
#  'we': 191,
#  'their': 192,
#  'many': 193,
#  'review': 194,
#  'light': 195,
#  'say': 196,
#  'sure': 197,
#  'find': 198,
#  're': 199,
#  'plug': 200,
#  'buttons': 201,
#  'seems': 202,
#  'fine': 203,
#  'something': 204,
#  'different': 205,
#  'where': 206,
#  'never': 207,
#  'clear': 208,
#  'should': 209,
#  'side': 210,
#  'unit': 211,
#  'able': 212,
#  'cheap': 213,
#  'times': 214,
#  'being': 215,
#  'design': 216,
#  'going': 217,
#  'once': 218,
#  'volume': 219,
#  'having': 220,
#  'charged': 221,
#  'pocket': 222,
#  'music': 223,
#  'purchased': 224,
#  'actually': 225,
#  'apple': 226,
#  'life': 227,
#  'tried': 228,
#  'hours': 229,
#  'big': 230,
#  'last': 231,
#  'through': 232,
#  'she': 233,
#  'hold': 234,
#  'overall': 235,
#  'amazon': 236,
#  'size': 237,
#  'always': 238,
#  'may': 239,
#  'happy': 240,
#  'who': 241,
#  'top': 242,
#  'come': 243,
#  'll': 244,
#  'give': 245,
#  'speaker': 246,
#  'item': 247,
#  'people': 248,
#  'getting': 249,
#  'rubber': 250,
#  'found': 251,
#  'protectors': 252,
#  'touch': 253,
#  'cord': 254,
#  'black': 255,
#  'worth': 256,
#  'days': 257,
#  'worked': 258,
#  'protect': 259,
#  'those': 260,
#  'camera': 261,
#  'definitely': 262,
#  'charges': 263,
#  'otterbox': 264,
#  'every': 265,
#  'less': 266,
#  'feels': 267,
#  'full': 268,
#  'received': 269,
#  'place': 270,
#  'headphones': 271,
#  'bad': 272,
#  'front': 273,
#  'fast': 274,
#  'quite': 275,
#  'end': 276,
#  'part': 277,
#  'stars': 278,
#  'issue': 279,
#  'bottom': 280,
#  'months': 281,
#  'purchase': 282,
#  'extra': 283,
#  'money': 284,
#  'ordered': 285,
#  'call': 286,
#  'micro': 287,
#  'batteries': 288,
#  'her': 289,
#  'stylus': 290,
#  'almost': 291,
#  'android': 292,
#  'several': 293,
#  'cell': 294,
#  'ports': 295,
#  'isn': 296,
#  'away': 297,
#  'try': 298,
#  'set': 299,
#  'high': 300,
#  'he': 301,
#  'pack': 302,
#  'highly': 303,
#  'things': 304,
#  'excellent': 305,
#  'took': 306,
#  'white': 307,
#  'won': 308,
#  'here': 309,
#  'yet': 310,
#  'hand': 311,
#  'ever': 312,
#  'home': 313,
#  'needed': 314,
#  'dropped': 315,
#  'thought': 316,
#  'free': 317,
#  'problems': 318,
#  'blue': 319,
#  'wanted': 320,
#  'job': 321,
#  'couple': 322,
#  'nexus': 323,
#  'mount': 324,
#  'probably': 325,
#  'issues': 326,
#  'itself': 327,
#  'original': 328,
#  'mah': 329,
#  'piece': 330,
#  'everything': 331,
#  'update': 332,
#  'quickly': 333,
#  'anything': 334,
#  'might': 335,
#  'three': 336,
#  'old': 337,
#  'longer': 338,
#  'reviews': 339,
#  'box': 340,
#  'either': 341,
#  'clip': 342,
#  'adapter': 343,
#  'tablet': 344,
#  'why': 345,
#  'wall': 346,
#  'drop': 347,
#  'said': 348,
#  'chargers': 349,
#  'left': 350,
#  'card': 351,
#  'remove': 352,
#  'others': 353,
#  'bulky': 354,
#  'order': 355,
#  'bubbles': 356,
#  'cables': 357,
#  'wife': 358,
#  'slim': 359,
#  'such': 360,
#  'own': 361,
#  'turn': 362,
#  'exactly': 363,
#  'built': 364,
#  'calls': 365,
#  'working': 366,
#  'second': 367,
#  'fact': 368,
#  'htc': 369,
#  'deal': 370,
#  'anyone': 371,
#  'ipod': 372,
#  'products': 373,
#  'colors': 374,
#  'wish': 375,
#  'awesome': 376,
#  'feature': 377,
#  'thin': 378,
#  'stand': 379,
#  'simple': 380,
#  'protects': 381,
#  'included': 382,
#  'already': 383,
#  'grip': 384,
#  'went': 385,
#  'nothing': 386,
#  'fully': 387,
#  'ones': 388,
#  'glass': 389,
#  'inside': 390,
#  'etc': 391,
#  'plus': 392,
#  'voice': 393,
#  'expected': 394,
#  'low': 395,
#  'especially': 396,
#  'least': 397,
#  'dust': 398,
#  'carry': 399,
#  'cute': 400,
#  'our': 401,
#  'plugged': 402,
#  'comfortable': 403,
#  'between': 404,
#  'weeks': 405,
#  'tell': 406,
#  'super': 407,
#  'hear': 408,
#  'although': 409,
#  'solid': 410,
#  'year': 411,
#  'add': 412,
#  'seem': 413,
#  'gets': 414,
#  'install': 415,
#  'ok': 416,
#  'cut': 417,
#  'until': 418,
#  'replacement': 419,
#  'service': 420,
#  'short': 421,
#  'soft': 422,
#  'read': 423,
#  'each': 424,
#  'let': 425,
#  'sturdy': 426,
#  'hands': 427,
#  'covers': 428,
#  'app': 429,
#  'audio': 430,
#  'reason': 431,
#  'buying': 432,
#  'durable': 433,
#  'mine': 434,
#  'edges': 435,
#  'takes': 436,
#  'mobile': 437,
#  'difficult': 438,
#  'motorola': 439,
#  'maybe': 440,
#  'instead': 441,
#  'week': 442,
#  'wasn': 443,
#  'kind': 444,
#  'led': 445,
#  'easier': 446,
#  'must': 447,
#  'large': 448,
#  'material': 449,
#  'bulk': 450,
#  'protective': 451,
#  'haven': 452,
#  'holds': 453,
#  'line': 454,
#  'apps': 455,
#  'slightly': 456,
#  'minutes': 457,
#  'under': 458,
#  'open': 459,
#  'real': 460,
#  'star': 461,
#  'years': 462,
#  'needs': 463,
#  'weight': 464,
#  'completely': 465,
#  'month': 466,
#  'press': 467,
#  'change': 468,
#  'features': 469,
#  'scratches': 470,
#  'heavy': 471,
#  'next': 472,
#  'droid': 473,
#  'dock': 474,
#  'type': 475,
#  'point': 476,
#  'holster': 477,
#  'brand': 478,
#  'expensive': 479,
#  'picture': 480,
#  'sometimes': 481,
#  'his': 482,
#  'sides': 483,
#  'cool': 484,
#  'gave': 485,
#  'wireless': 486,
#  'pen': 487,
#  'arrived': 488,
#  'belt': 489,
#  'wouldn': 490,
#  'noise': 491,
#  'version': 492,
#  'stay': 493,
#  'pay': 494,
#  'goes': 495,
#  'store': 496,
#  'cost': 497,
#  'clean': 498,
#  'surface': 499,
#  'trying': 500,
#  'provides': 501,
#  'amazing': 502,
#  'connection': 503,
#  'shipping': 504,
#  'wear': 505,
#  'done': 506,
#  'mini': 507,
#  'capacity': 508,
#  'decent': 509,
#  'broke': 510,
#  'smooth': 511,
#  'standard': 512,
#  'due': 513,
#  'tight': 514,
#  'protected': 515,
#  'play': 516,
#  'allows': 517,
#  'pros': 518,
#  'else': 519,
#  'expect': 520,
#  'fall': 521,
#  'switch': 522,
#  'wrong': 523,
#  'quick': 524,
#  'seller': 525,
#  'simply': 526,
#  'test': 527,
#  'face': 528,
#  'oem': 529,
#  'instructions': 530,
#  'rather': 531,
#  'available': 532,
#  'loves': 533,
#  'liked': 534,
#  'making': 535,
#  'handy': 536,
#  'designed': 537,
#  'company': 538,
#  'provided': 539,
#  'loved': 540,
#  'external': 541,
#  'customer': 542,
#  'portable': 543,
#  'half': 544,
#  'smartphone': 545,
#  'often': 546,
#  'gps': 547,
#  'close': 548,
#  'started': 549,
#  'access': 550,
#  'water': 551,
#  'computer': 552,
#  'edge': 553,
#  'gives': 554,
#  'running': 555,
#  'connector': 556,
#  'travel': 557,
#  'replace': 558,
#  'package': 559,
#  'provide': 560,
#  'video': 561,
#  'decided': 562,
#  'cannot': 563,
#  'extremely': 564,
#  'help': 565,
#  'pleased': 566,
#  'run': 567,
#  'silicone': 568,
#  'leave': 569,
#  'guess': 570,
#  'recommended': 571,
#  'connect': 572,
#  'verizon': 573,
#  'experience': 574,
#  'pair': 575,
#  'range': 576,
#  'tip': 577,
#  'during': 578,
#  'nicely': 579,
#  'means': 580,
#  'bright': 581,
#  'similar': 582,
#  'keeps': 583,
#  'purse': 584,
#  'apply': 585,
#  'thick': 586,
#  'scratch': 587,
#  'couldn': 588,
#  'someone': 589,
#  'uses': 590,
#  'kindle': 591,
#  'red': 592,
#  'headphone': 593,
#  'taking': 594,
#  'air': 595,
#  'compared': 596,
#  'within': 597,
#  'outlet': 598,
#  'break': 599,
#  'finally': 600,
#  'connected': 601,
#  'extended': 602,
#  'absolutely': 603,
#  'room': 604,
#  'bag': 605,
#  'jack': 606,
#  'stick': 607,
#  'output': 608,
#  'packaging': 609,
#  'holding': 610,
#  'headsets': 611,
#  'says': 612,
#  'usually': 613,
#  'smart': 614,
#  'start': 615,
#  'user': 616,
#  'yes': 617,
#  'finish': 618,
#  'dual': 619,
#  'anker': 620,
#  'holder': 621,
#  'model': 622,
#  'smaller': 623,
#  'blackberry': 624,
#  'data': 625,
#  'disappointed': 626,
#  'pink': 627,
#  'loose': 628,
#  'larger': 629,
#  'useful': 630,
#  'night': 631,
#  'strong': 632,
#  'seen': 633,
#  'looked': 634,
#  'mind': 635,
#  'multiple': 636,
#  'show': 637,
#  'four': 638,
#  'person': 639,
#  'installed': 640,
#  'push': 641,
#  'whole': 642,
#  'slide': 643,
#  'head': 644,
#  'myself': 645,
#  'google': 646,
#  'amount': 647,
#  'past': 648,
#  'value': 649,
#  'speakers': 650,
#  'jabra': 651,
#  'talk': 652,
#  'together': 653,
#  'snug': 654,
#  'thanks': 655,
#  'pictures': 656,
#  'cons': 657,
#  'display': 658,
#  'putting': 659,
#  'idea': 660,
#  'lg': 661,
#  'friends': 662,
#  'fairly': 663,
#  'non': 664,
#  'outside': 665,
#  'everyone': 666,
#  'doing': 667,
#  'style': 668,
#  'support': 669,
#  'ears': 670,
#  'area': 671,
#  'noticed': 672,
#  'cards': 673,
#  'via': 674,
#  'against': 675,
#  'signal': 676,
#  'drops': 677,
#  'along': 678,
#  'shell': 679,
#  'friend': 680,
#  'tested': 681,
#  'return': 682,
#  'lights': 683,
#  'unless': 684,
#  'paid': 685,
#  'number': 686,
#  'finger': 687,
#  'prefer': 688,
#  'sent': 689,
#  'nokia': 690,
#  'sleek': 691,
#  'control': 692,
#  'added': 693,
#  'offers': 694,
#  'huge': 695,
#  'hour': 696,
#  'loud': 697,
#  'tpu': 698,
#  'watch': 699,
#  'adds': 700,
#  'difference': 701,
#  'sim': 702,
#  'given': 703,
#  'otherwise': 704,
#  'recharge': 705,
#  'leather': 706,
#  'daughter': 707,
#  'compact': 708,
#  'damage': 709,
#  'secure': 710,
#  'defender': 711,
#  'onto': 712,
#  'annoying': 713,
#  'convenient': 714,
#  'properly': 715,
#  'bumper': 716,
#  'option': 717,
#  'believe': 718,
#  'keyboard': 719,
#  'impressed': 720,
#  'complaints': 721,
#  'allow': 722,
#  'metal': 723,
#  'dont': 724,
#  'flat': 725,
#  'normal': 726,
#  'level': 727,
#  'market': 728,
#  'cheaper': 729,
#  'course': 730,
#  'function': 731,
#  'later': 732,
#  'faster': 733,
#  'ago': 734,
#  'worry': 735,
#  'apart': 736,
#  'house': 737,
#  'turned': 738,
#  'matte': 739,
#  'slip': 740,
#  'evo': 741,
#  'ac': 742,
#  'amp': 743,
#  'system': 744,
#  'mode': 745,
#  'glad': 746,
#  'favorite': 747,
#  'previous': 748,
#  'snap': 749,
#  'owned': 750,
#  'single': 751,
#  'us': 752,
#  'driving': 753,
#  'soon': 754,
#  'lost': 755,
#  'flash': 756,
#  'plan': 757,
#  'advertised': 758,
#  'pull': 759,
#  'regular': 760,
#  'build': 761,
#  'tablets': 762,
#  'juice': 763,
#  'listen': 764,
#  'beautiful': 765,
#  'feet': 766,
#  'twice': 767,
#  'tiny': 768,
#  'hd': 769,
#  'stays': 770,
#  'film': 771,
#  'rate': 772,
#  'corners': 773,
#  'current': 774,
#  'length': 775,
#  'important': 776,
#  'gift': 777,
#  'suction': 778,
#  'gs': 779,
#  'husband': 780,
#  'coming': 781,
#  'complaint': 782,
#  'slippery': 783,
#  'kept': 784,
#  'performance': 785,
#  'hope': 786,
#  'stock': 787,
#  'sample': 788,
#  'supposed': 789,
#  'unfortunately': 790,
#  'bank': 791,
#  'thank': 792,
#  'matter': 793,
#  'shows': 794,
#  'notice': 795,
#  'care': 796,
#  'slot': 797,
#  'attached': 798,
#  'plantronics': 799,
#  'above': 800,
#  'cords': 801,
#  'five': 802,
#  'lightning': 803,
#  'satisfied': 804,
#  'rating': 805,
#  'installation': 806,
#  'sounds': 807,
#  'stereo': 808,
#  'covered': 809,
#  'wallet': 810,
#  'except': 811,
#  'listening': 812,
#  'bigger': 813,
#  'controls': 814,
#  'pieces': 815,
#  'earbuds': 816,
#  'near': 817,
#  'cause': 818,
#  'family': 819,
#  'stuff': 820,
#  'higher': 821,
#  'application': 822,
#  'cloth': 823,
#  'warranty': 824,
#  'answer': 825,
#  'items': 826,
#  'kickstand': 827,
#  'careful': 828,
#  'move': 829,
#  'mp': 830,
#  'lose': 831,
#  'text': 832,
#  'helps': 833,
#  'including': 834,
#  'okay': 835,
#  'radio': 836,
#  'offer': 837,
#  'plugs': 838,
#  'choice': 839,
#  'anyway': 840,
#  'described': 841,
#  'desk': 842,
#  'surprised': 843,
#  'iphones': 844,
#  'green': 845,
#  'felt': 846,
#  'backup': 847,
#  'today': 848,
#  'send': 849,
#  'bass': 850,
#  'spare': 851,
#  'ended': 852,
#  'minor': 853,
#  'pro': 854,
#  'pairing': 855,
#  'space': 856,
#  'beat': 857,
#  'check': 858,
#  'gb': 859,
#  'unlike': 860,
#  'belkin': 861,
#  'held': 862,
#  'barely': 863,
#  'speed': 864,
#  'laptop': 865,
#  'skin': 866,
#  'flip': 867,
#  'carrying': 868,
#  'poor': 869,
#  'mm': 870,
#  'email': 871,
#  'purpose': 872,
#  'reading': 873,
#  'microphone': 874,
#  'spigen': 875,
#  'flimsy': 876,
#  'main': 877,
#  'considering': 878,
#  'seemed': 879,
#  'trent': 880,
#  'keeping': 881,
#  'saw': 882,
#  'glare': 883,
#  'wait': 884,
#  'usage': 885,
#  'true': 886,
#  'dead': 887,
#  'based': 888,
#  'mic': 889,
#  'credit': 890,
#  'options': 891,
#  'wifi': 892,
#  'constantly': 893,
#  'talking': 894,
#  'protecting': 895,
#  'broken': 896,
#  'manufacturer': 897,
#  'solution': 898,
#  'sticky': 899,
#  'opinion': 900,
#  'immediately': 901,
#  'office': 902,
#  'inexpensive': 903,
#  'aren': 904,
#  'live': 905,
#  'fantastic': 906,
#  'totally': 907,
#  'actual': 908,
#  'spend': 909,
#  'son': 910,
#  'placed': 911,
#  'playing': 912,
#  'hole': 913,
#  'lighter': 914,
#  'thicker': 915,
#  'corner': 916,
#  'road': 917,
#  'windows': 918,
#  'hot': 919,
#  'opening': 920,
#  'trouble': 921,
#  'giving': 922,
#  'scratched': 923,
#  'additional': 924,
#  'tech': 925,
#  'player': 926,
#  'otter': 927,
#  'lasted': 928,
#  'name': 929,
#  'fingers': 930,
#  'position': 931,
#  'stuck': 932,
#  'arm': 933,
#  'seconds': 934,
#  'lasts': 935,
#  'across': 936,
#  'software': 937,
#  'hit': 938,
#  'earpiece': 939,
#  'base': 940,
#  'certainly': 941,
#  'tape': 942,
#  'entire': 943,
#  'videos': 944,
#  'dash': 945,
#  'shipped': 946,
#  'armor': 947,
#  'likely': 948,
#  'flashlight': 949,
#  'turns': 950,
#  'possible': 951,
#  'waste': 952,
#  'feeling': 953,
#  'lightweight': 954,
#  'fell': 955,
#  'outer': 956,
#  'replaced': 957,
#  'nearly': 958,
#  'fire': 959,
#  'paired': 960,
#  'appears': 961,
#  'indicator': 962,
#  'contact': 963,
#  'honest': 964,
#  'cup': 965,
#  'none': 966,
#  'ability': 967,
#  'clearly': 968,
#  'trip': 969,
#  'stylish': 970,
#  'falls': 971,
#  'securely': 972,
#  'pouch': 973,
#  'sprint': 974,
#  'removed': 975,
#  'pick': 976,
#  'lip': 977,
#  'windshield': 978,
#  'save': 979,
#  'pad': 980,
#  'lower': 981,
#  'daily': 982,
#  'flexible': 983,
#  'drive': 984,
#  'photos': 985,
#  'addition': 986,
#  'tab': 987,
#  'directly': 988,
#  'older': 989,
#  'somewhat': 990,
#  'gotten': 991,
#  'whatever': 992,
#  'form': 993,
#  'pin': 994,
#  'dirty': 995,
#  'texture': 996,
#  'lint': 997,
#  'basic': 998,
#  'behind': 999,
#  ...}

# %%
vocab_int2word = {model.wv.key_to_index[w]:model.wv.get_vector(w, norm=True) for w in vocab_list}
# . Bu sözlük, kelimelerin model tarafından öğrenilen vektörlerini anahtar-değer (key-value) çiftleri olarak saklar

# %%
vocab_int2word  # kelime indekslerini ve vektörlerini döndürür
# Out:
# {0: array([ 6.94181994e-02,  1.18129037e-01, -5.13313636e-02, -5.90617917e-02,
#         -4.01573107e-02, -5.40364310e-02,  1.26240045e-01,  2.84647107e-01,
#         -3.58697996e-02, -1.35244012e-01, -6.86006024e-02, -5.84004745e-02,
#          7.10079297e-02,  1.00893117e-01, -6.77196011e-02, -1.01524107e-01,
#         -3.97188887e-02,  1.18833646e-01,  4.64924462e-02, -8.67921934e-02,
#          3.21885794e-02, -1.45799726e-01,  2.06812739e-01, -1.33129418e-01,
#          5.43009453e-02, -9.64717492e-02, -4.11192365e-02, -9.98946875e-02,
#         -1.74470603e-01,  5.40151633e-02,  9.49024260e-02, -5.71595170e-02,
#         -1.65613852e-02, -1.69919655e-01,  3.47247384e-02,  1.27045423e-01,
#          1.01733953e-01,  3.17393690e-02,  2.79076640e-02, -1.10930353e-01,
#         -1.58430580e-02,  2.42862180e-02, -8.96868482e-02,  6.17096312e-02,
#          2.09684130e-02,  5.04185148e-02, -1.87630042e-01, -5.73112294e-02,
#         -1.94062829e-01,  1.25741661e-01,  1.09888412e-01, -1.12710036e-01,
#         -0.01479405, -0.12457434,  0.17056245, -0.00573715, -0.05682537,
#          0.03361559, -0.0243052 ,  0.02672932,  0.03117002,  0.10784785,
#         -0.0052304 , -0.11671254, -0.01351944, -0.24052528, -0.01415775,
#          0.05784898, -0.04870359,  0.1250288 , -0.17299938, -0.10216828,
#          0.05950868,  0.09871345,  0.02367584,  0.10230666, -0.01023564,
#         -0.00925053, -0.05598992, -0.03305522,  0.181081  ,  0.05199255,
#         -0.02185414, -0.20757051,  0.02852416,  0.0639683 ,  0.10755671,
#          0.0604042 , -0.1193874 ,  0.07402334, -0.01718335,  0.00096047,
#          0.1967147 ,  0.02134702,  0.05080271, -0.04575652,  0.06023451,
#          0.0014801 ,  0.02717794,  0.00554407, -0.02881354, -0.17511955,
#          0.13975517, -0.00767766,  0.07999402, -0.08847542,  0.08142622,
#          0.05957577,  0.112982  ,  0.18685806, -0.00914596,  0.08681873,
#          0.16332908, -0.07608269, -0.07195196, -0.06625275,  0.06678819,
#         -0.21480054,  0.09904713, -0.08854965, -0.00259071, -0.08371165,
#         -0.13886525,  0.16139267, -0.01139961,  0.04321159, -0.03705022,
#          0.02719881,  0.00672707,  0.1180867 ,  0.05796663,  0.07111143,
#          0.15851225, -0.06527871, -0.01577003, -0.06257246, -0.10346436],
#        dtype=float32),
#  17: array([-0.02945639,  0.0774833 , -0.10898276, -0.09548955,  0.0491297 ,
#         -0.19054031,  0.17548077,  0.25401497,  0.04823503, -0.00324693,
#          0.04354611, -0.1074002 , -0.00876172, -0.10972464,  0.12967892,
#          0.0300196 ,  0.10100532,  0.11159801,  0.04723169, -0.11411029,
#          0.08062665, -0.06784578,  0.11197043,  0.07575706,  0.0832219 ,
#          0.05619932,  0.03175982,  0.06578632, -0.13905273,  0.07604191,
#          0.06276727, -0.06044517,  0.04662827, -0.08712517,  0.01049403,
#          0.15212204,  0.10985487,  0.10983521,  0.09843858, -0.04974744,
#          0.05190076, -0.04619617,  0.03957093,  0.11602318, -0.11026353,
#          0.12482044, -0.15998349,  0.0134415 , -0.1851597 ,  0.12534736,
#          0.0550261 , -0.10644543,  0.13579279,  0.09424677, -0.127253  ,
#          0.01301265,  0.00486843, -0.0266217 , -0.10792095,  0.01094012,
#         -0.05410393, -0.02420481, -0.05366411,  0.02800156,  0.10201307,
#          0.14188997,  0.04638947,  0.10974475,  0.01932908, -0.02862503,
#         -0.05795919,  0.17987785,  0.12893675, -0.0336351 ,  0.05578785,
#          0.13460802,  0.07202393, -0.13770212, -0.03524283, -0.00282359,
#         -0.03216745, -0.0209546 , -0.13178387,  0.02663493, -0.09946293,
#         -0.22299166,  0.08833066,  0.08613178,  0.03578092, -0.14389268,
#          0.12034293, -0.0455632 ,  0.11138931,  0.04534345, -0.00332314,
#          0.29437244,  0.05722598,  0.12905169,  0.07597304, -0.02970147],
#        dtype=float32),
#  18: array([ 0.1422873 , -0.0132268 , -0.11252271,  0.13823037, -0.01327678,
#         -0.14467059,  0.08817574,  0.20709486, -0.12046435, -0.08430087,
#         -0.10266384, -0.07426994, -0.05135601,  0.10718616,  0.03901464,
#         -0.13533896, -0.05792508,  0.01074269,  0.00510799, -0.0395917 ,
#         -0.0548686 ,  0.04902865,  0.06034474, -0.00071454,  0.08067925,
#          0.0425573 , -0.02067217, -0.08271739, -0.19332117, -0.01580825,
#          0.0116946 , -0.19028005, -0.01693847, -0.0849175 , -0.05207385,
#          0.12285963,  0.2138768 , -0.00722782,  0.04871743, -0.03000194,
#          0.14200984,  0.07213923, -0.09329919,  0.14217375,  0.04875306,
#          0.03718427, -0.04348253,  0.16533658, -0.05738136,  0.05959623,
#          0.15124877, -0.1526792 ,  0.12754136, -0.10945038, -0.02746313,
#          0.15962166,  0.04595409,  0.0569362 ,  0.03330012, -0.06419329,
#         -0.07261319,  0.00761219,  0.00565765, -0.03606044, -0.18723685,
#          0.14415352,  0.04628927,  0.10941648, -0.03769289,  0.07855552,
#          0.10120381,  0.11139856, -0.06567153, -0.05673289, -0.04905432,
#          0.27687612, -0.02343361, -0.0161867 , -0.18590479,  0.05223152,
#         -0.05506773,  0.17991085, -0.08184984,  0.14708783, -0.02241989,
#         -0.06949785,  0.25842112,  0.03961151,  0.11812625, -0.07196157,
#         -0.05002692, -0.03585202,  0.07186729, -0.05931467,  0.10528068,
#          0.1169354 ,  0.01328134, -0.02676109,  0.01520351, -0.05622979],
#        dtype=float32),
#  21: array([ 0.10025228,  0.16058266, -0.0582954 , -0.09765504,  0.0614532 ,
#          0.04701638,  0.13889913,  0.16975744, -0.03112257, -0.02821925,
#         -0.12411033, -0.13181017,  0.04419325,  0.05635309,  0.05574698,
#         -0.15641841,  0.02587122,  0.10794719, -0.09636133, -0.04692584,
#          0.02428468, -0.02290937,  0.11833552,  0.03368791,  0.07733405,
#         -0.0048243 , -0.05065612,  0.04090505, -0.18158111,  0.0123062 ,
#          0.0765609 , -0.08874144,  0.0991184 , -0.27575353, -0.14083882,
#          0.20983097,  0.19046162,  0.09505612,  0.09023447, -0.05361838,
#          0.05273346, -0.01201449, -0.06936459,  0.16210133, -0.00882209,
#          0.04109234, -0.05455979,  0.02106851, -0.00786811,  0.1409182 ,
#          0.2648983 , -0.00880619,  0.06798525, -0.06541701, -0.0193797 ,
#          0.02331081,  0.06131117, -0.0953177 , -0.01444952,  0.12110368,
#          0.01134927, -0.00327195, -0.02269158, -0.04215388, -0.09755449,
#          0.08095059,  0.03635028,  0.07459173, -0.06445084,  0.01930167,
#         -0.0286951 ,  0.09025054,  0.07521849,  0.14086206,  0.03416127,
#          0.1344991 , -0.05242828, -0.06957721, -0.16743286,  0.11004099,
#         -0.20246784,  0.10097329, -0.08155321,  0.01659086, -0.1396922 ,
#         -0.22736831,  0.06290475, -0.07006121,  0.01530307, -0.01520885,
#          0.05969976,  0.00885805,  0.11616859,  0.00243373,  0.0219919 ,
#          0.2501599 ,  0.03429851, -0.00792853,  0.05486402, -0.07259194],
#        dtype=float32),
#  22: array([ 0.00338578,  0.19873591,  0.01261633, -0.03286009,  0.06718063,
#         -0.12775585,  0.18451579, -0.04097837,  0.07805054, -0.07525077,
#          0.03017778, -0.0999476 ,  0.05892726,  0.03754285,  0.0376109 ,
#         -0.0178478 , -0.04143038, -0.11613441, -0.02021469, -0.13905503,
#         -0.07489841,  0.06331329, -0.16431753,  0.16356951, -0.17513101,
#          0.1082505 ,  0.07974331,  0.20679468, -0.02656394,  0.01298589,
#          0.08113679, -0.02273882,  0.04829193,  0.01696416,  0.02207953,
#          0.17080167,  0.01632774, -0.08393359, -0.03725446, -0.20239188],
#        dtype=float32),
#  30: array([ 0.07591182,  0.05243219,  0.0552865 , -0.11215349, -0.02770079,
#         -0.02395112,  0.12545456,  0.28198767,  0.07233517, -0.10214923,
#          0.01484964,  0.12896848, -0.11189303,  0.04011489,  0.0083115 ,
#         -0.0349818 , -0.0875056 ,  0.02874498,  0.11106773, -0.15804045,
#         -0.05569619, -0.08945583,  0.16044894, -0.18647435, -0.00317466,
#         -0.01872529, -0.00759715,  0.02413561, -0.15409824, -0.11373839,
#          0.13605547, -0.08210303,  0.04903194, -0.13299198, -0.11753808,
#          0.0131915 ,  0.05926916, -0.02855704, -0.11501051,  0.09704977,
#          0.02812471, -0.07650114, -0.0155323 ,  0.05053295, -0.0880776 ,
#          0.07025274,  0.05176353,  0.18435097, -0.0798205 ,  0.15644196,
#          0.10880617, -0.07965479,  0.0482007 , -0.02101393, -0.20666748,
#          0.18369848,  0.16115023,  0.19323048, -0.03171609,  0.01993313,
#         -0.0458729 , -0.05998627,  0.03462151,  0.0761386 ,  0.03016159,
#          0.23972331,  0.07455986,  0.11983604, -0.13733087,  0.05192837,
#          0.01600727, -0.04678978,  0.01144233,  0.1410105 ,  0.04065107,
#          0.12571837, -0.06658728,  0.07506661, -0.09037678,  0.06602918,
#         -0.08870462,  0.06837554,  0.0194656 ,  0.0208767 , -0.06655108,
#         -0.06317179,  0.12498543,  0.03406295, -0.05434658, -0.09659567,
#          0.01229007,  0.06359848,  0.14762034,  0.00744014, -0.10054997,
#          0.14984567,  0.0812399 ,  0.16457175, -0.04727715, -0.1330904 ],
#        dtype=float32),
#  31: array([ 0.12907524,  0.16164613, -0.15142302,  0.05087401,  0.07046547,
#         -0.12106489, -0.02114601,  0.22976343, -0.0579735 , -0.09714326,
#          0.00117777,  0.14602508,  0.11820785,  0.13415232, -0.11272226,
#         -0.11255091,  0.08859631,  0.05679448,  0.13783029, -0.12269799,
#          0.06322092, -0.05610064,  0.01242252, -0.10605218,  0.14514035,
#         -0.0752285 ,  0.03429061, -0.13072038, -0.13926236,  0.09460495,
#          0.00785578, -0.14338183, -0.0246269 , -0.1957706 , -0.10384229,
#          0.2240793 ,  0.01652726,  0.07971089,  0.10874987, -0.07566945,
#          0.00350844,  0.03395692,  0.12680179,  0.22544618, -0.07129474,
#          0.05058186, -0.03582036,  0.00933729,  0.02670761,  0.09279411,
#          0.1535946 ,  0.08369466,  0.0549569 , -0.02529422, -0.03687096,
#         -0.01762174,  0.09697483,  0.10264277, -0.01496463,  0.00925545,
#         -0.125584  ,  0.04082537, -0.03614385,  0.05911544,  0.04239698,
# ...
#          0.12233619,  0.00635149, -0.1337172 ,  0.07364269,  0.08758292,
#          0.21175773, -0.05756082,  0.01806424, -0.04276009, -0.08714429],
#        dtype=float32),
#  990: array([ 0.12056423,  0.00144266,  0.11909413,  0.07827321, -0.11786774,
#         -0.13682845,  0.05763869,  0.31660953, -0.16659422, -0.02816553,
#         -0.11602429, -0.206504  , -0.02467592,  0.11083077, -0.00402326,
#         -0.0377136 , -0.18573917,  0.06178049,  0.08236341,  0.11151882,
#         -0.00887943, -0.11307865,  0.00036823, -0.08796701,  0.10386481,
#          0.17569277, -0.10118426, -0.02783547, -0.11741697, -0.06564021,
#          0.1268096 ,  0.09573863,  0.19135873, -0.20519236,  0.08765774,
#          0.05542695,  0.10665678, -0.04456031,  0.04813255, -0.00134644,
#         -0.13177179, -0.03188083, -0.08109229,  0.12185168,  0.14591764,
#         -0.12265888, -0.03645289,  0.04490674, -0.10228716,  0.04559693,
#          0.03787114, -0.0802449 ,  0.07567021, -0.13884594, -0.01986335,
#          0.11633559,  0.12661187,  0.03017638,  0.06786315,  0.10663345,
#          0.06239387,  0.00946051, -0.02683155, -0.05903975, -0.08543614,
#          0.10315596,  0.22704141, -0.00658065,  0.02596459,  0.00104044,
#         -0.1655152 ,  0.0529892 ,  0.15115109, -0.07389357,  0.12521042,
#          0.11720415, -0.10056768,  0.03227604, -0.00538786,  0.00186146,
#         -0.14508441,  0.03915137, -0.07807127,  0.04921548, -0.01542438,
#          0.0114347 ,  0.03972706,  0.01250038,  0.13464075, -0.01437286,
#          0.11379938,  0.04321172,  0.0187394 ,  0.01239026, -0.00639494,
#          0.08808986, -0.12887008, -0.00849715, -0.09694637, -0.02613868],
#        dtype=float32),
#  991: array([ 0.06261566,  0.17500399,  0.00353297,  0.1065954 ,  0.13991386,
#         -0.1696578 ,  0.16352913,  0.03606934,  0.03094639,  0.00396328,
#         -0.04213223, -0.11350552, -0.0942086 , -0.02366842,  0.0560621 ,
#          0.06749231,  0.04304606,  0.08216094, -0.08468355, -0.10140797,
#          0.10917266, -0.01759347,  0.16227625,  0.02147047,  0.03320044,
#          0.05192042,  0.03848717, -0.02121487, -0.10599715, -0.03586277,
#          0.06075659,  0.13618162,  0.13663824, -0.14149626, -0.17271534,
#          0.0629466 ,  0.05668946,  0.07117894,  0.04301786,  0.04760886,
#          0.06535825, -0.14157781, -0.03007105, -0.06213817, -0.08024425,
#          0.12643753,  0.05202971,  0.01580028,  0.00753511,  0.02455828,
#          0.04352688, -0.09793685, -0.09013183, -0.03735944, -0.06592572,
#          0.08546758,  0.0287807 , -0.07034285, -0.0446988 ,  0.1629667 ,
#          0.02100953, -0.03004447, -0.13013917, -0.16390574,  0.02175684,
#          0.3208884 ,  0.20437643,  0.13204052, -0.11105459, -0.11011927,
#          0.12954047, -0.08002544,  0.10795125,  0.00311033, -0.0045491 ,
#          0.07926409,  0.25814116, -0.03055218, -0.01742578, -0.02297702,
#         -0.25243467, -0.06842986, -0.01098677,  0.03392933, -0.13317421,
#         -0.1269744 , -0.06164468, -0.0796472 , -0.03597215,  0.05369123,
#          0.08467437, -0.22043818, -0.05179154, -0.01606031,  0.04668497,
#         -0.00644495, -0.26444826,  0.1331654 ,  0.10857087, -0.12790382,
#          0.02536906,  0.09921754, -0.17880656,  0.02060406, -0.17659214,
#         -0.11180904, -0.04853186,  0.16391055,  0.01348807,  0.0399682 ,
#          0.04662385, -0.00179614, -0.0608738 , -0.05862772, -0.0388781 ,
#         -0.01242752, -0.0605575 ,  0.11119101, -0.14641777, -0.05218267,
#          0.14274444,  0.01695151,  0.03653517,  0.1899981 , -0.11887787,
#         -0.10672772,  0.03769365, -0.11655843,  0.02743744,  0.00327685,
#         -0.0664392 ,  0.11318772, -0.05668144, -0.03311435,  0.0663735 ,
#          0.03346252,  0.02021648, -0.01154985,  0.09839462, -0.09415264,
#         -0.05483151,  0.17062193, -0.12542574, -0.08747571,  0.03395415,
#         -0.06724896,  0.02928152,  0.05726824,  0.01783151, -0.03722204,
#          0.0662258 ,  0.05209976,  0.03608189, -0.26521277,  0.16767414,
#         -0.15373188,  0.03345919, -0.03250731,  0.04081009, -0.00110443,
#         -0.10845644,  0.24115942,  0.01860003, -0.00893253,  0.05506401,
#         -0.09513959, -0.03787478, -0.02033223,  0.06337291, -0.23847269,
#          0.01838289,  0.20227675,  0.11639301,  0.11042268, -0.05118756,
#          0.05939082,  0.12646717,  0.05840597, -0.07712784, -0.06659167,
#          0.07467093, -0.01065236,  0.03417977, -0.04843802, -0.05291267],
#        dtype=float32),
#  ...}

# %%
vocab_int2word[4697]
# Out:
# array([ 0.23371696,  0.14116225,  0.09403869,  0.07595507,  0.07984642,
#         0.09919146,  0.22803007,  0.13634503, -0.03192644,  0.08368894,
#        -0.08921527, -0.16313015,  0.11729302, -0.04957659,  0.03162155,
#         0.14600936, -0.02600583,  0.14534283,  0.0943578 , -0.09583825,
#         0.04792016,  0.15195857,  0.08200265, -0.00326954,  0.00822163,
#         0.07344974, -0.13676184,  0.02685939, -0.13034421,  0.01353804,
#         0.07293899,  0.12343916,  0.12155976, -0.08418179, -0.02828683,
#         0.0433173 ,  0.25241476,  0.1002509 ,  0.06469642,  0.06961599,
#         0.02228048, -0.06917268,  0.05447729, -0.00819838,  0.06355379,
#        -0.12720214, -0.09989544, -0.0076817 , -0.09316429,  0.04955938,
#         0.01400036,  0.04071441,  0.02077082,  0.24179651, -0.10321981,
#        -0.04247403,  0.11631961, -0.04064941, -0.12609522, -0.05238934,
#        -0.03572119,  0.02630859,  0.0271055 , -0.00171504, -0.20880963,
#         0.04811369,  0.10763972,  0.06394096, -0.27094954,  0.10060092,
#        -0.04479345,  0.01955662,  0.14611469, -0.09519259,  0.12676273,
#         0.00739079, -0.2084762 ,  0.05684686, -0.02184082, -0.00814988,
#        -0.06166233,  0.12832282,  0.02972405, -0.01591324, -0.08276232,
#        -0.13866943, -0.03455785,  0.0335097 ,  0.00512752,  0.12832876,
#         0.0091306 ,  0.0354575 ,  0.09028336,  0.0139982 , -0.11660342,
#        -0.05722814,  0.00530972,  0.01818694,  0.04583798,  0.06991786],
#       dtype=float32)

# %%
import numpy as np
one_hot = np.zeros(shape=(1,vocab_len))

one_hot[0,model.wv.key_to_index['awesome']] = 1
